# %%
# Scatter plot

# %%
import matplotlib.pyplot as plt

people = ["Person A", "Person B", "Person C", "Person D", "Person E", 
          "Person F", "Person G", "Person H", "Person I", "Person J"]
age = [22, 25, 30, 35, 40, 45, 50, 55, 60, 65]
blood_pressure = [110, 115, 120, 122, 125, 130, 135, 123, 145, 150]

colors = ["green" if bp < 129 else "red" for bp in blood_pressure]

plt.scatter(age, blood_pressure, color=colors, s=blood_pressure, marker="<", alpha=0.5)
plt.title("Age VS Blood Pressure")
plt.xlabel("Age")
plt.ylabel("Blood Pressure")

plt.grid()

# %%
# Here we observe The blood pressure is increase as age is increase (Co-relation find)
# We found a outline also here.

# %%
# colormap
people = ["Person A", "Person B", "Person C", "Person D", "Person E", 
          "Person F", "Person G", "Person H", "Person I", "Person J"]
age = [22, 25, 30, 35, 40, 45, 50, 55, 60, 65]
blood_pressure = [110, 115, 120, 122, 125, 130, 135, 123, 145, 150]

plt.scatter(age, blood_pressure,  s=blood_pressure, cmap="OrRd", c = blood_pressure) # We have to pass both cmap value and c 
# Many builtin cmap value are available refer from documentation
# c value is where we want to map the color.
plt.title("Age VS Blood Pressure")
plt.xlabel("Age")
plt.ylabel("Blood Pressure")

plt.grid()

plt.colorbar()

for i in range(len(people)):
    plt.annotate(people[i], xy=(age[i], blood_pressure[i]), xytext=(age[i]+1, blood_pressure[i]) ) # Text, point, position

plt.xlim(min(age), max(age)+10)
plt.ylim(min(blood_pressure), max(blood_pressure)+5)
# Out:
# (110.0, 155.0)
